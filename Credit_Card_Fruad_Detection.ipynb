# %% [markdown]
# <a href="https://colab.research.google.com/github/me-hul/Self-Projects/blob/main/Credit_Card_Fruad_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cc=pd.read_csv('/content/drive/MyDrive/Data/creditcard.csv')
cc.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
rows,column=cc.shape
print(rows,column)
# Out:
# 284807 31

# %%
cc.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
cc.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
cc.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
cc.duplicated().any()
# Out:
# True

# %%
cc.duplicated().sum()
# Out:
# 1081

# %%
#duplicate values remove
cc=cc.drop_duplicates()
cc.shape
# Out:
# (283726, 31)

# %%
cc.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
cc.duplicated().any()
# Out:
# False

# %%
cc["Class"].value_counts()
#0=legitimate txn
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %%
cc["Class"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Class'>

# %%
#Imbalanced data
percentagedata=cc["Class"].value_counts()/len(cc)*100
percentagedata
# Out:
# Class
# 0    99.83329
# 1     0.16671
# Name: count, dtype: float64

# %%
#stat
cc.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean    94811.077600       0.005917      -0.004135       0.001613
# std     47481.047891       1.948026       1.646703       1.508682
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     54204.750000      -0.915951      -0.600321      -0.889682
# 50%     84692.500000       0.020384       0.063949       0.179963
# 75%    139298.000000       1.316068       0.800283       1.026960
# max    172792.000000       2.454930      22.057729       9.382558
#
#                   V4             V5             V6             V7  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean       -0.002966       0.001828      -0.001139       0.001801
# std         1.414184       1.377008       1.331931       1.227664
# min        -5.683171    -113.743307     -26.160506     -43.557242
# ...

# %%
# y= Dependant
# x= Indep
x=cc.drop("Class", axis=1)
y=cc["Class"]

# %% [markdown]
# #Handling Imbalanced Data using Resampling using SMOTE
#
# 1.   List item
# 2.   List item

# %%
x.shape
# Out:
# (283726, 30)

# %%
y.shape
# Out:
# (283726,)

# %%
# !pip install imblearn

# %%
from imblearn.over_sampling import SMOTE

# %%
smote=SMOTE(random_state=42)

# %%
x_smote,y_smote=smote.fit_resample(x,y)

# %%
x_smote.shape #shape of variables changed to balance the clasess
# Out:
# (566506, 30)

# %%
y_smote.value_counts()
# Out:
# Class
# 0    283253
# 1    283253
# Name: count, dtype: int64

# %%
from collections import Counter
print("Og dataset",Counter(y))
print("New dataset",Counter(y_smote))
# Out:
# Og dataset Counter({0: 283253, 1: 473})
# New dataset Counter({0: 283253, 1: 283253})

# %%
### Data Visualistation

# %%
fraud_data=cc[cc["Class"]==1]
legit_data=cc[cc["Class"]==0]

# %%
fraud_data['Amount'].plot(kind='hist',bins=50,color='red')
# Out:
# <Axes: ylabel='Frequency'>

# %%
legit_data['Amount'].plot(kind='hist',bins=50,color='red')
# Out:
# <Axes: ylabel='Frequency'>

# %%
fraud_data['Amount'].plot(kind='box')
# Out:
# <Axes: >

# %%
legit_data['Amount'].plot(kind='box')
# Out:
# <Axes: >

# %%
#correl matrix before Imbalanced data
cor_imbal=cc.corr()
cor_imbal
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# Time    1.000000  0.117927 -0.010556 -0.422054 -0.105845  0.173223 -0.063279
# V1      0.117927  1.000000  0.006875 -0.008112  0.002257 -0.007036  0.000413
# V2     -0.010556  0.006875  1.000000  0.005278 -0.001495  0.005210 -0.000594
# V3     -0.422054 -0.008112  0.005278  1.000000  0.002829 -0.006879 -0.001511
# V4     -0.105845  0.002257 -0.001495  0.002829  1.000000  0.001744 -0.000880
# V5      0.173223 -0.007036  0.005210 -0.006879  0.001744  1.000000 -0.000938
# V6     -0.063279  0.000413 -0.000594 -0.001511 -0.000880 -0.000938  1.000000
# V7      0.085335 -0.009173  0.007425 -0.011721  0.004657 -0.008709  0.000436
# V8     -0.038203 -0.001168  0.002899 -0.001815  0.000890  0.001430  0.003036
# V9     -0.007861  0.001828 -0.000274 -0.003579  0.002154 -0.001213 -0.000734
# V10     0.031068  0.000815  0.000620 -0.009632  0.002753 -0.006050 -0.002180
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(cor_imbal,annot=False, cmap='plasma',linewidth=0.5)
plt.title("Correlation Matrix for imbalanced Data")
plt.show()

# %%
#correl matrix after balanced data
cor_bal=x_smote.corr()
plt.figure(figsize=(10,10))
sns.heatmap(cor_bal,annot=False, cmap='plasma',linewidth=0.5)
plt.title("Correlation Matrix for balanced Data")
plt.show()

# %%
custom_palette=sns.color_palette(['blue','gold'])
plt.figure(figsize=(10,10))
sns.countplot(x='Class',data=cc,palette=custom_palette)
plt.title("Class Distribution")
plt.show()
# Out:
# <ipython-input-36-cd634e4ffa05>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Class',data=cc,palette=custom_palette)

# %%
custom_palette=sns.color_palette(['blue','gold'])
plt.figure(figsize=(10,10))
sns.countplot(x=y_smote,palette=custom_palette)
plt.title("Class Distribution after SMOTE resampling")
plt.xlabel("Class(0:legitimate, 1: Fraud)")
plt.ylabel("Count")
plt.show()
# Out:
# <ipython-input-37-12c77ef3456b>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=y_smote,palette=custom_palette)

# %%
#Split the dataset
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_smote,y_smote,test_size=0.2,random_state=42)

# %%
#Model building
from sklearn.linear_model import LogisticRegression
log_reg=LogisticRegression(random_state=42)
log_reg.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=42)

# %%
y_pred= log_reg.predict(x_test)

# %%
#classification report:
from sklearn.metrics import confusion_matrix,classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97     56463
#            1       0.98      0.96      0.97     56839
#
#     accuracy                           0.97    113302
#    macro avg       0.97      0.97      0.97    113302
# weighted avg       0.97      0.97      0.97    113302

# %%
confusion=confusion_matrix(y_test,y_pred)
confusion
# Out:
# array([[55224,  1239],
#        [ 2120, 54719]])

# %%
#visualise the array
confusion_df= pd.DataFrame(confusion, columns=["predicted negative(0)","predicted positive(1)"],
                           index=["actual negative(0)","actual positive(1)"])
confusion_df
# Out:
#                     predicted negative(0)  predicted positive(1)
# actual negative(0)                  55224                   1239
# actual positive(1)                   2120                  54719

# %%
plt.figure(figsize=(10,10))
sns.heatmap(confusion,annot=True, fmt="d",cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
#ROC-AUC Curve and Plot ROC Curve

from sklearn.metrics import roc_curve,auc
y_scores=log_reg.predict_proba(x_test)[:,1]
fpr,tpr,thresholds=roc_curve(y_test,y_pred)
roc_auc=auc(fpr,tpr)

plt.figure(figsize=(10,10))
plt.plot(fpr,tpr,color="blue",lw=2,label="ROC curve(area=%0.2f)" %roc_auc)
plt.plot([0,1],[0,1],color="red",lw=2,linestyle="--")
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver Operating Characteristic")
plt.legend(loc="lower right")
plt.show()
